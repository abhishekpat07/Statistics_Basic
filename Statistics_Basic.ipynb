# %% [markdown]
# #1.  Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales.
# - Data can be categorized into two main types:
# 1. Qualitative Data: It refers to information about qualities, or information that cannot be measured. It's usually descriptive and textual.
# 2. Quantitative Data: It is numerical. It's used information that can be counted.
# - Nominal Scale: It is the 1st level of measurement scale in which thw numbers serves as tags or lables to ca=lassify or identify the objects.
# - Ordinal Scale: It is 2nd level of measurement that reports the ordering and ranking of data without establishing the degree of variation between them.
# - Interval Scale: The interval scale is the 3rd level of measurement scale. It is defined as a quantitative measurement scale in which the difference between the two variables is meaningful.
# - Ratio Scale: The ratio scale is the 4th level of measurement scale, which is quantitative. It is a type of variable measurement scale. It allows researchers to compare the differences or intervals.

# %% [markdown]
# #2. What are the measures of central tendency, and when should you use each? Discuss the mean, median, and mode with examples and situations where each is appropriate.
# - Central Tendencies in Statistics are the numerical values that are used to represent mid-value or central value a large collection of numerical data.
# - Mean:The avergare of set of numbers.To find the mean, add all the numbers in the set and divide by the number of values.
# Ex:- (2+4+6+8+10)/5 = 6
# - Median: The middle value of a set of numbers.To find the median, arrange the numbers in order from least to greatest and find the middle.
# Ex:- 2,4.6.8.10. The median is 6.
# - Mode: The number taht occur most often in a set of numbers.
# Ex:- 2,3,5,3,4,8,3,6,3. The mode is 3.

# %% [markdown]
# #3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
# - Concept of dispersion in statistics is a way to descrobe how spread out or scattered the data is around an average value. It helps to understand if the data points are close together or far apart. It shows the variablity or consistency in a set of data. There are different measures of dispersion like range, variance and standard deviation.
# Variance is a measure of dispersion that takes into account the spread of all data points in a data set. And, Standard deviation which is simply the square root of the variance.

# %% [markdown]
# #4. What is a box plot, and what can it tell you about the distribution of data?
# - Box Plot is a graphical method to visualize data distrobution for gaining insit=hts and making informed decisions. Box plot is atype of chart that depicts a group of numerical data through their quartiles.

# %% [markdown]
# #5. Discuss the role of random sampling in making inferences about populations.
# -Random sampling is a statistical method of selecting a sunset of individuals or items from a large population in which each member has an equal chance of being chosen. It's hepl to ensure that the sample selected is representative of large population and Allow for generalisations to be made about the population based on the sample.

# %% [markdown]
# #6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
# - Skewness in statistics is the measure of how much the probability distribution of a random variable deviates from the normal distribution. There are three types of skewness:
# 1. Right Skew
# 2. Left Skew
# 3. Zero Skew
# - Skewness significantly impacts data interpretation by revealing the asymmetry in a distribution.

# %% [markdown]
# #7. What is the interquartile range (IQR), and how is it used to detect outliers?
# - The Interquartile Range defines the difference between the third and the first quartile.
# - Interqurtile Range = Upper Quartile - Lower Quartile = Q3 -Q1.
# - The IQR method of outlier detection is a method that dictates that any data point in a boxplot that's more than 1.5 IQR points bwlow the first quartile data or more than 1.5 IQR points above the third quartile data is considered an outlier.

# %% [markdown]
# #8. Discuss the conditions under which the binomial distribution is used.
# - The binomial distribution describes te behavior of a count varibales x if the following condition apply:
# 1. The number of observation n is fixed.
# 2. Each observation is independent
# 3. Each observation represents one of two outcomes.

# %% [markdown]
# #9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).
# - The normal distribution is probabilty distribution that is symmetric and bell-shaped. It is also known as the Gaussian distribution.
# - The empirical rule (68-95-99.7 rule), tells where most of the values lie in ni=ormal distribution: Arround 68% of value are within 1 standard deviation of mean. Around 95% of values are within 2 standard deviations of the mean. Around 99.7% values are within 3 standard deviations of the mean.

# %% [markdown]
# #10. Provide a real-life example of a Poisson process and calculate the probability for a specific event.
# - P(X=k) = λk * e– λ / k!
#
# Where:
# λ: mean number of successes that occur during a specific interval
# k: number of successes
# e: a constant equal to approximately 2.71828
#
# - Number of Website visitors per Hours:
# Suppose a given website receives an average of 20 visitors per hour. According to the formula in abouve mention we get:
#
# P(X> 25 visitors) = 0.11218
# P(X> 30 visitors) = 0.01347
# P(x> 35 visitors) = 0.00080

# %% [markdown]
# #11. Explain what a random variable is and differentiate between discrete and continuous random variables.
# - A random varible is a rule that assigns a number to each outcome in a sample space. Random variables can be discrete or continuos. A discrete random varibale is type of random variable that has a countable number of distinct values, such as heads or tails, or playing cards. A continuous random variable can reflect an infinite number of potential values, such as the averge rainfall in a region.

# %% [markdown]
# #12. Provide an example dataset, calculate both covariance and correlation, and interpret the results.
# -

# %%
import numpy as np

# Data for X (Height) and Y (Weight)
X = np.array([160, 170, 180, 150, 175])
Y = np.array([55, 60, 65, 50, 62])

# Step 1: Calculate Covariance
covariance = np.cov(X, Y, bias=False)[0][1]

# Step 2: Calculate Correlation
correlation = np.corrcoef(X, Y)[0][1]

covariance, correlation
# Out:
# (71.5, 0.9993892830835875)
